# %%
import pandas as pd
import numpy as np

# %%
train_set = pd.read_csv('./data/train.csv')

# %%
train_set.mean()
# Out:
# MWG         75.695513
# NWG         75.884118
# KWG         25.599127
# MDIMC       14.464719
# NDIMC       14.495119
# MDIMA       17.377880
# NDIMB       17.394602
# KWI          5.004159
# VWM          2.342739
# VWN          2.347128
# STRM         0.500449
# STRN         0.499551
# SA           0.485896
# SB           0.485967
# Run_time     4.365376
# dtype: float64

# %%
train_set.std().to_numpy()
# Out:
# array([41.98419881, 41.99594928,  7.83857358,  8.09928844,  8.12179282,
#         9.36365247,  9.36964422,  3.00000789,  1.86385224,  1.86166473,
#         0.50000159,  0.50000159,  0.49980282,  0.49980484,  0.84060615])
